# %%
INDbidang = [ 'Internet of Things', 'Machine Learning', 'Jaringan Komputer',' Pemrograman Web' ]
for i in INDbidang:
   print(i)
# Out:
# Internet of Things
# Machine Learning
# Jaringan Komputer
#  Pemrograman Web
